# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os

# %%
image_size = (150, 150)
batch_size = 32
MODEL = "detectSelfie_model"

# %% [markdown]
# # Import dataset

# %%
# Download selfie dataset from kaggle
if not os.path.exists("data/Selfie-Image-Detection-Dataset"):
    # Instruction for installing credential at https://github.com/Kaggle/kaggle-api
    from kaggle.api.kaggle_api_extended import KaggleApi
    api = KaggleApi()
    api.authenticate()

    # Selfie dataset at https://www.kaggle.com/jigrubhatt/selfieimagedetectiondataset
    # Download to sub-directory data/
    api.dataset_download_files('jigrubhatt/selfieimagedetectiondataset', 'data/', unzip=True)

# %%
# Set up training and validation dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "data/Selfie-Image-Detection-Dataset/Training_data",
    labels="inferred",
    label_mode="int",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "data/Selfie-Image-Detection-Dataset/Validation_data",
    labels="inferred",
    label_mode="int",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 62895 files belonging to 2 classes.
# Found 7862 files belonging to 2 classes.

# %%
# Show class names of the dataset
class_names = train_ds.class_names
print(class_names)
# Out:
# ['NonSelfie', 'Selfie']

# %%
# Visualize the dataset
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# # Create transfer learning model

# %%
# Import Xception model
base_model = keras.applications.Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False)

# Freeze the base model
base_model.trainable = False

# %%
# Set up data augmentation preprocessing layers
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
        layers.experimental.preprocessing.RandomZoom(0.3, 0.3),
        layers.experimental.preprocessing.RandomTranslation(0.2, 0.2),
    ]
)

# Create new model on top
inputs = keras.Input(shape=(150, 150, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

# %%
# Pre-trained Xception weights requires that input be normalized
# from (0, 255) to a range (-1., +1.), the normalization layer
# does the following, outputs = (inputs - mean) / sqrt(var)

norm_layer = keras.layers.experimental.preprocessing.Normalization()
mean = np.array([127.5] * 3)
var = mean ** 2

# Scale inputs to [-1, +1]
x = norm_layer(x)
norm_layer.set_weights([mean, var])

# We make sure that the base_model is running in inference mode here,
# by passing `training=False`.
x = base_model(x, training=False)

# Convert features of shape `base_model.output_shape[1:]` to vectors
x = keras.layers.GlobalAveragePooling2D()(x)

# A Dense classifier with a single unit (binary classification)
x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)

# %% [markdown]
# # Train model

# %%
# Train model
epochs = 20

model.summary()
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=[keras.metrics.BinaryAccuracy()])
train_history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Epoch 1/20
# 1966/1966 [==============================] - 5493s 3s/step - loss: 0.1898 - binary_accuracy: 0.9256 - val_loss: 0.1258 - val_binary_accuracy: 0.9520
# Epoch 2/20
# 1966/1966 [==============================] - 4466s 2s/step - loss: 0.1372 - binary_accuracy: 0.9487 - val_loss: 0.1203 - val_binary_accuracy: 0.9554
# Epoch 3/20
# 1966/1966 [==============================] - 4317s 2s/step - loss: 0.1313 - binary_accuracy: 0.9513 - val_loss: 0.1191 - val_binary_accuracy: 0.9540
# Epoch 4/20
# 1966/1966 [==============================] - 6268s 3s/step - loss: 0.1329 - binary_accuracy: 0.9500 - val_loss: 0.1089 - val_binary_accuracy: 0.9573
# Epoch 5/20
# 1966/1966 [==============================] - 5266s 3s/step - loss: 0.1286 - binary_accuracy: 0.9511 - val_loss: 0.1253 - val_binary_accuracy: 0.9529
# Epoch 6/20
# 1966/1966 [==============================] - 5448s 3s/step - loss: 0.1316 - binary_accuracy: 0.9511 - val_loss: 0.1147 - val_binary_accuracy: 0.9565
# Epoch 7/20
# 1966/1966 [==============================] - 5893s 3s/step - loss: 0.1269 - binary_accuracy: 0.9535 - val_loss: 0.1218 - val_binary_accuracy: 0.9538
# Epoch 8/20
# 1966/1966 [==============================] - 4075s 2s/step - loss: 0.1321 - binary_accuracy: 0.9510 - val_loss: 0.1228 - val_binary_accuracy: 0.9532
# Epoch 9/20
# 1966/1966 [==============================] - 3793s 2s/step - loss: 0.1301 - binary_accuracy: 0.9516 - val_loss: 0.1106 - val_binary_accuracy: 0.9571
# Epoch 10/20
# 1966/1966 [==============================] - 3787s 2s/step - loss: 0.1295 - binary_accuracy: 0.9519 - val_loss: 0.1149 - val_binary_accuracy: 0.9565
# Epoch 11/20
# 1966/1966 [==============================] - 3782s 2s/step - loss: 0.1319 - binary_accuracy: 0.9504 - val_loss: 0.1322 - val_binary_accuracy: 0.9501
# Epoch 12/20
# 1966/1966 [==============================] - 3757s 2s/step - loss: 0.1320 - binary_accuracy: 0.9498 - val_loss: 0.1036 - val_binary_accuracy: 0.9620
# Epoch 13/20
# 1966/1966 [==============================] - 3758s 2s/step - loss: 0.1331 - binary_accuracy: 0.9513 - val_loss: 0.1156 - val_binary_accuracy: 0.9556
# Epoch 14/20
# 1966/1966 [==============================] - 3751s 2s/step - loss: 0.1326 - binary_accuracy: 0.9511 - val_loss: 0.1010 - val_binary_accuracy: 0.9627
# Epoch 15/20
# 1966/1966 [==============================] - 3753s 2s/step - loss: 0.1332 - binary_accuracy: 0.9498 - val_loss: 0.1056 - val_binary_accuracy: 0.9592
# Epoch 16/20
# 1966/1966 [==============================] - 3759s 2s/step - loss: 0.1271 - binary_accuracy: 0.9528 - val_loss: 0.1206 - val_binary_accuracy: 0.9546
# Epoch 17/20
# 1966/1966 [==============================] - 3759s 2s/step - loss: 0.1322 - binary_accuracy: 0.9499 - val_loss: 0.1223 - val_binary_accuracy: 0.9546
# Epoch 18/20
# 1966/1966 [==============================] - 3851s 2s/step - loss: 0.1284 - binary_accuracy: 0.9524 - val_loss: 0.1172 - val_binary_accuracy: 0.9564
# Epoch 19/20
# 1966/1966 [==============================] - 4366s 2s/step - loss: 0.1323 - binary_accuracy: 0.9501 - val_loss: 0.1065 - val_binary_accuracy: 0.9587
# Epoch 20/20
# 1966/1966 [==============================] - 5503s 3s/step - loss: 0.1269 - binary_accuracy: 0.9522 - val_loss: 0.1298 - val_binary_accuracy: 0.9500
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-324cc702ae97> in <module>
#       8
#       9 # Save training history as a dictionary
# ---> 10 with open('/trainHistoryDict', 'wb') as file_pi:
#      11     pickle.dump(train_history.history, file_pi)
#
# OSError: [Errno 30] Read-only file system: '/trainHistoryDict'

# %%
import pandas as pd
# convert the train_history.history dict to a pandas DataFrame:     
train_hist_df = pd.DataFrame(train_history.history) 

# save to json:  
hist_json_file = 'train_history.json' 
with open(hist_json_file, mode='w') as f:
    train_hist_df.to_json(f)

# or save to csv: 
hist_csv_file = 'train_history.csv'
with open(hist_csv_file, mode='w') as f:
    train_hist_df.to_csv(f)

# %%
# Creates a SavedModel
model.save(MODEL)
# Out:
# INFO:tensorflow:Assets written to: detectSelfie_model/assets

# %%
# Evaluate training
acc = train_history.history['binary_accuracy']
val_acc = train_history.history['val_binary_accuracy']

loss = train_history.history['loss']
val_loss = train_history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Fine-tuning model
base_model.trainable = True
model.summary()

model.compile(
    optimizer=keras.optimizers.Adam(1e-5),  # Low learning rate
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 5

fine_tuning_history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 150, 150, 3)       0
# _________________________________________________________________
# normalization (Normalization (None, 150, 150, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 20,863,536
# Trainable params: 20,809,001
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/5
# 1966/1966 [==============================] - 14787s 8s/step - loss: 0.0926 - binary_accuracy: 0.9668 - val_loss: 0.0575 - val_binary_accuracy: 0.9793
# Epoch 2/5
# 1966/1966 [==============================] - 12584s 6s/step - loss: 0.0516 - binary_accuracy: 0.9817 - val_loss: 0.0381 - val_binary_accuracy: 0.9864
# Epoch 3/5
# 1966/1966 [==============================] - 12112s 6s/step - loss: 0.0424 - binary_accuracy: 0.9844 - val_loss: 0.0393 - val_binary_accuracy: 0.9864
# Epoch 4/5
# 1966/1966 [==============================] - 12359s 6s/step - loss: 0.0359 - binary_accuracy: 0.9873 - val_loss: 0.0255 - val_binary_accuracy: 0.9914
# Epoch 5/5
# 1966/1966 [==============================] - 11997s 6s/step - loss: 0.0329 - binary_accuracy: 0.9885 - val_loss: 0.0262 - val_binary_accuracy: 0.9908

# %%
# convert the fine_tuning_history.history dict to a pandas DataFrame:     
fine_tuning_hist_df = pd.DataFrame(fine_tuning_history.history) 

# save to json:  
hist_json_file = 'fine_tuning_history.json' 
with open(hist_json_file, mode='w') as f:
    fine_tuning_hist_df.to_json(f)

# or save to csv: 
hist_csv_file = 'fine_tuning_history.csv'
with open(hist_csv_file, mode='w') as f:
    fine_tuning_hist_df.to_csv(f)

# %%
# Creates a SavedModel
model.save("final_detectSelfie_model")
# Out:
# INFO:tensorflow:Assets written to: final_detectSelfie_model/assets

# %%
#Evaluate fine-tuning
acc = fine_tuning_history.history['binary_accuracy']
val_acc = fine_tuning_history.history['val_binary_accuracy']

loss = fine_tuning_history.history['loss']
val_loss = fine_tuning_history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Evaluate accuracy

# %%
# Load test dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  "data/Selfie-Image-Detection-Dataset/Test_data",
    labels='inferred',
    label_mode='int',
    seed=123,
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 7862 files belonging to 2 classes.

# %%
# Usage: making a single prediction
image_path = "data/Selfie-Image-Detection-Dataset/Test_data/Selfie/Selfie42906.jpg"
img = keras.preprocessing.image.load_img(image_path, target_size=image_size)

plt.imshow(img)

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = predictions[0]

if (score > 0.5):
    print("Image is a Selfie")
    print(score)
else:
    print("Image is not a Selfie")
    print(score)
# Out:
# Image is a Selfie
# [0.9939537]

# %%
# predictions on test dataset
predictions = np.array([])
labels =  np.array([])
for images, y in test_ds:
    for i in range(len(y)):
        scores = model.predict(images)
        if (scores[i] > 0.5):
            prediction = np.ones(1)
        else:
            prediction = np.zeros(1)
        predictions = np.concatenate([predictions, prediction])
        labels = np.concatenate([labels, np.array([y.numpy()[i]])])

# %%
# Total error count
print('Number of errors :', sum(x != 0 for x in (predictions - labels)), 'out of', len(predictions))
# Out:
# Number of errors : 58 out of 7862

# %%
# Accuracy score
from sklearn.metrics import accuracy_score 
print('accuracy_score :', accuracy_score(labels, predictions))
# Out:
# accuracy_score : 0.9926227423047571

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error
print('mean_squared_error :', mean_squared_error(labels, predictions))
# Out:
# mean_squared_error : 0.00737725769524294

# %%
# Plot confusion matrix
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(labels, predictions)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=test_ds.class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[3897   34]
#  [  24 3907]]
# Normalized confusion matrix
# [[0.99 0.01]
#  [0.01 0.99]]

# %%
# Remove used data
shutil.rmtree("data/Selfie-Image-Detection-Dataset")
